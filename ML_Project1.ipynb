# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
from math import sqrt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from pmdarima import auto_arima
from fbprophet import Prophet
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import RNN
from keras.layers import Dropout
from keras.layers import *
from keras.callbacks import EarlyStopping
import tensorflow as tf
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 10>()
#       8 from sklearn.model_selection import train_test_split
#       9 from pmdarima import auto_arima
# ---> 10 from fbprophet import Prophet
#      11 from sklearn.preprocessing import MinMaxScaler
#      12 from tensorflow.keras import layers
#
# ModuleNotFoundError: No module named 'fbprophet'

# %% [markdown]
# # Creating dataframes for stocks

# %%
# The stocks we'll use for this analysis (top 4 market capital banks)
stock_names = ['HDFC', 'ICICI', 'SBI', 'KOTAK']

path = "/home/vinay/Downloads/NIFTY_50/"

# %%
# HDFC data

df1 = pd.read_csv(path + "HDFCBANK.csv")
df1.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
# HDFC data

df1.set_index("Date", drop=False, inplace=True)
HDFC = df1.loc[:, ['Date', 'Open', 'High', 'Low', 'Close', 'VWAP', 'Volume', 'Turnover']]
HDFC.head()
# Out:
#                   Date    Open    High     Low   Close    VWAP  Volume  \
# Date
# 2000-01-03  2000-01-03  166.00  170.00  166.00  170.00  169.52   33259
# 2000-01-04  2000-01-04  182.00  183.45  171.00  173.80  174.99  168710
# 2000-01-05  2000-01-05  170.00  173.90  165.00  166.95  169.20  159820
# 2000-01-06  2000-01-06  168.00  170.00  165.30  168.30  168.44   85026
# 2000-01-07  2000-01-07  162.15  171.00  162.15  168.35  166.79   85144
#
#                 Turnover
# Date
# 2000-01-03  5.638122e+11
# 2000-01-04  2.952261e+12
# 2000-01-05  2.704094e+12
# 2000-01-06  1.432166e+12
# 2000-01-07  1.420158e+12

# %%
# ICICI data

df2 = pd.read_csv(path + "ICICIBANK.csv")
df2.set_index("Date", drop=False, inplace=True)
ICICI = df2.loc[:, ['Date', 'Open', 'High', 'Low', 'Close', 'VWAP', 'Volume', 'Turnover']]
ICICI.head()
# Out:
#                   Date   Open   High    Low  Close   VWAP  Volume  \
# Date
# 2000-01-03  2000-01-03  74.35  74.75  71.40  74.75  73.20  286260
# 2000-01-04  2000-01-04  73.05  78.50  71.00  73.05  73.38  296264
# 2000-01-05  2000-01-05  70.00  73.50  67.50  69.50  70.85  227624
# 2000-01-06  2000-01-06  71.00  74.00  69.55  70.05  72.04  275149
# 2000-01-07  2000-01-07  69.00  72.50  66.00  67.40  68.72  138809
#
#                 Turnover
# Date
# 2000-01-03  2.095439e+12
# 2000-01-04  2.173893e+12
# 2000-01-05  1.612794e+12
# 2000-01-06  1.982121e+12
# 2000-01-07  9.538882e+11

# %%
# SBI data

df3 = pd.read_csv(path + "SBIN.csv")
df3.set_index("Date", drop=False, inplace=True)
SBI = df3.loc[:, ['Date', 'Open', 'High', 'Low', 'Close', 'VWAP', 'Volume', 'Turnover',]]
SBI.head()
# Out:
#                   Date    Open    High     Low   Close    VWAP   Volume  \
# Date
# 2000-01-03  2000-01-03  236.00  243.65  234.25  243.65  240.83  2373228
# 2000-01-04  2000-01-04  243.65  262.00  238.85  259.10  251.46  4495741
# 2000-01-05  2000-01-05  249.00  264.70  245.00  248.45  252.35  3434058
# 2000-01-06  2000-01-06  252.00  268.00  252.00  261.00  262.18  6658801
# 2000-01-07  2000-01-07  261.50  279.90  255.00  273.30  269.02  7873985
#
#                 Turnover
# Date
# 2000-01-03  5.715338e+13
# 2000-01-04  1.130506e+14
# 2000-01-05  8.666008e+13
# 2000-01-06  1.745817e+14
# 2000-01-07  2.118287e+14

# %%
# KOTAK data

df4 = pd.read_csv(path + "KOTAKBANK.csv")
df4.set_index("Date", drop=False, inplace=True)
KOTAK = df4.loc[:, ['Date', 'Open', 'High', 'Low', 'Close', 'VWAP', 'Volume', 'Turnover']]
KOTAK.head()
# Out:
#                   Date   Open    High     Low   Close    VWAP  Volume  \
# Date
# 2000-01-03  2000-01-03  220.0  229.35  220.00  229.35  229.13    7086
# 2000-01-04  2000-01-04  247.7  247.70  225.25  246.95  244.12   73681
# 2000-01-05  2000-01-05  229.0  240.00  227.20  228.40  233.75  105799
# 2000-01-06  2000-01-06  235.1  239.00  217.00  225.90  226.84   40202
# 2000-01-07  2000-01-07  213.0  219.00  207.85  208.85  209.94   24463
#
#                 Turnover
# Date
# 2000-01-03  1.623640e+11
# 2000-01-04  1.798729e+12
# 2000-01-05  2.473093e+12
# 2000-01-06  9.119546e+11
# 2000-01-07  5.135747e+11

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Summary Stats of HDFC

HDFC.describe()
# Out:
#               Open         High          Low        Close         VWAP  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1007.472767  1019.986939   993.822211  1007.330390  1006.929263
# std     635.461516   641.444674   629.502818   635.675021   635.481917
# min     162.150000   167.900000   157.000000   163.400000   161.400000
# 25%     482.112500   486.912500   473.100000   480.200000   479.512500
# 50%     939.350000   953.950000   922.175000   935.725000   937.455000
# 75%    1423.525000  1440.000000  1399.000000  1421.000000  1420.567500
# max    2566.000000  2583.300000  2553.700000  2565.800000  2570.700000
#
#              Volume      Turnover
# count  5.306000e+03  5.306000e+03
# mean   2.102580e+06  2.448837e+14
# std    3.970048e+06  4.778103e+14
# min    1.042000e+03  2.291142e+10
# 25%    3.058325e+05  1.640025e+13
# 50%    9.444650e+05  1.150443e+14
# 75%    2.123647e+06  2.154477e+14
# max    1.005650e+08  1.426400e+16

# %%
# General info of HDFC

HDFC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5306 entries, 2000-01-03 to 2021-04-30
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5306 non-null   object
#  1   Open      5306 non-null   float64
#  2   High      5306 non-null   float64
#  3   Low       5306 non-null   float64
#  4   Close     5306 non-null   float64
#  5   VWAP      5306 non-null   float64
#  6   Volume    5306 non-null   int64
#  7   Turnover  5306 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 373.1+ KB

# %% [markdown]
# **VWAP variations of all stocks over time**

# %%
stock_list = [HDFC, ICICI, SBI, KOTAK]

plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, stock in enumerate(stock_list, 1):
    plt.subplot(2, 2, i)
    stock['VWAP'].plot()
    plt.ylabel('VWAP')
    plt.xlabel(None)
    plt.title(f"VWAP of {stock_names[i - 1]}")
    
plt.tight_layout()

# %% [markdown]
# **Total volume of all stock being traded each day**

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, stock in enumerate(stock_list, 1):
    plt.subplot(2, 2, i)
    stock['Volume'].plot()
    plt.ylabel('Volume')
    plt.xlabel(None)
    plt.title(f"Sales Volume for {stock_names[i - 1]}")
    
plt.tight_layout()

# %% [markdown]
# **Moving average of the all stocks**

# %%
# average is taken over a specific period of time, like 3 months, 6 months, 1 year

ma_day = [90, 180, 365]

for ma in ma_day:
    for stock in stock_list:
        column_name = f"MA for {ma} days"
        stock[column_name] = stock['VWAP'].rolling(ma).mean()
        

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

HDFC[['VWAP', 'MA for 90 days', 'MA for 180 days', 'MA for 365 days']].plot(ax=axes[0,0])
axes[0,0].set_title('HDFC')

ICICI[['VWAP', 'MA for 90 days', 'MA for 180 days', 'MA for 365 days']].plot(ax=axes[0,1])
axes[0,1].set_title('ICICI')

SBI[['VWAP', 'MA for 90 days', 'MA for 180 days', 'MA for 365 days']].plot(ax=axes[1,0])
axes[1,0].set_title('SBI')

KOTAK[['VWAP', 'MA for 90 days', 'MA for 180 days', 'MA for 365 days']].plot(ax=axes[1,1])
axes[1,1].set_title('KOTAK')

fig.tight_layout()

# %% [markdown]
# **Daily return of the stock on average**

# %%
# using pct_change to find the percent change for each day

for stock in stock_list:
    stock['Daily Return'] = stock['Close'].pct_change()

# Then we'll plot the daily return percentage

fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(10)
fig.set_figwidth(15)

HDFC['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('HDFC')

ICICI['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('ICICI')

SBI['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('SBI')

KOTAK['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('KOTAK')

fig.tight_layout()

# %% [markdown]
# **Average daily return using a histogram**

# %%
plt.figure(figsize=(12, 9))

for i, stock in enumerate(stock_list, 1):
    plt.subplot(2, 2, i)
    stock['Daily Return'].hist(bins=100)
    plt.xlabel('Daily Return')
    plt.ylabel('Counts')
    plt.title(f'{stock_names[i - 1]}')
    plt.xlim(-0.2, 0.2)
    
plt.tight_layout()

# %% [markdown]
# **Correlation between different stocks closing prices**

# %%
VWAP_df = pd.DataFrame()

for i, stock in enumerate(stock_list, 1):
    VWAP_df[stock_names[i-1]] = stock['VWAP']
    
VWAP_df.head()
# Out:
#               HDFC  ICICI     SBI   KOTAK
# Date
# 2000-01-03  169.52  73.20  240.83  229.13
# 2000-01-04  174.99  73.38  251.46  244.12
# 2000-01-05  169.20  70.85  252.35  233.75
# 2000-01-06  168.44  72.04  262.18  226.84
# 2000-01-07  166.79  68.72  269.02  209.94

# %%
stock_returns = VWAP_df.pct_change()
stock_returns.head()
# Out:
#                 HDFC     ICICI       SBI     KOTAK
# Date
# 2000-01-03       NaN       NaN       NaN       NaN
# 2000-01-04  0.032268  0.002459  0.044139  0.065421
# 2000-01-05 -0.033088 -0.034478  0.003539 -0.042479
# 2000-01-06 -0.004492  0.016796  0.038954 -0.029561
# 2000-01-07 -0.009796 -0.046086  0.026089 -0.074502

# %%
# using jointplot to compare the daily returns of HDFC and ICICI

plot1 = sns.jointplot(x='HDFC', y='ICICI', data=stock_returns, kind='scatter')
plt.xlim(-0.3, 0.3)
plt.ylim(-0.3, 0.3)
plt.show()

# %%
# correlation pairplots for daily returns

sns.pairplot(stock_returns, kind='reg')

# %%
# correlation pairplots for VWAP

sns.pairplot(VWAP_df, kind='reg')

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 2, 1)
sns.heatmap(stock_returns.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock daily return')

plt.subplot(2, 2, 2)
sns.heatmap(VWAP_df.corr(), annot=True, cmap='summer')
plt.title('Correlation of stock VWAP')
# Out:
# Text(0.5, 1.0, 'Correlation of stock closing price')

# %% [markdown]
# **Value we put at risk by investing in a particular stock**

# %%
# by comparing the expected return with the standard deviation of the daily returns.

plt.figure(figsize=(10, 8))
plt.scatter(stock_returns.mean(), stock_returns.std(), s=60)
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(stock_returns.columns, stock_returns.mean(), stock_returns.std()):
    plt.annotate(label, xy=(x, y))

# %% [markdown]
# # Feature Engineering

# %%
# feature engineering

# stock to be predicted
stock = HDFC.copy()

lag_features = ["High", "Low", "Volume", "Turnover", "Close"]
window1 = 3
window2 = 7
window3 = 30

stock.reset_index(drop=True, inplace=True)

df_rolled_3d = stock[lag_features].rolling(window=window1, min_periods=0)
df_rolled_7d = stock[lag_features].rolling(window=window2, min_periods=0)
df_rolled_30d = stock[lag_features].rolling(window=window3, min_periods=0)

df_mean_3d = df_rolled_3d.mean().shift(1).reset_index().astype(np.float32)
df_mean_7d = df_rolled_7d.mean().shift(1).reset_index().astype(np.float32)
df_mean_30d = df_rolled_30d.mean().shift(1).reset_index().astype(np.float32)

df_std_3d = df_rolled_3d.std().shift(1).reset_index().astype(np.float32)
df_std_7d = df_rolled_7d.std().shift(1).reset_index().astype(np.float32)
df_std_30d = df_rolled_30d.std().shift(1).reset_index().astype(np.float32)

for feature in lag_features:
    stock[f"{feature}_mean_lag{window1}"] = df_mean_3d[feature]
    stock[f"{feature}_mean_lag{window2}"] = df_mean_7d[feature]
    stock[f"{feature}_mean_lag{window3}"] = df_mean_30d[feature]

    stock[f"{feature}_std_lag{window1}"] = df_std_3d[feature]
    stock[f"{feature}_std_lag{window2}"] = df_std_7d[feature]
    stock[f"{feature}_std_lag{window3}"] = df_std_30d[feature]

#     stock.fillna(stock.mean(numeric_only=True), inplace=True)

stock.set_index("Date", drop=False, inplace=True)

display(stock.head())
# Out:
#                   Date    Open    High     Low   Close    VWAP  Volume  \
# Date
# 2000-01-03  2000-01-03  166.00  170.00  166.00  170.00  169.52   33259
# 2000-01-04  2000-01-04  182.00  183.45  171.00  173.80  174.99  168710
# 2000-01-05  2000-01-05  170.00  173.90  165.00  166.95  169.20  159820
# 2000-01-06  2000-01-06  168.00  170.00  165.30  168.30  168.44   85026
# 2000-01-07  2000-01-07  162.15  171.00  162.15  168.35  166.79   85144
#
#                 Turnover  High_mean_lag3  High_mean_lag7  ...  \
# Date                                                      ...
# 2000-01-03  5.638122e+11             NaN             NaN  ...
# 2000-01-04  2.952261e+12      170.000000      170.000000  ...
# 2000-01-05  2.704094e+12      176.725006      176.725006  ...
# 2000-01-06  1.432166e+12      175.783340      175.783340  ...
# 2000-01-07  1.420158e+12      175.783340      174.337494  ...
#
#             Turnover_mean_lag30  Turnover_std_lag3  Turnover_std_lag7  \
# Date
# 2000-01-03                  NaN                NaN                NaN
# 2000-01-04         5.638122e+11                NaN                NaN
# 2000-01-05         1.758037e+12       1.688889e+12       1.688889e+12
# 2000-01-06         2.073389e+12       1.313207e+12       1.313207e+12
# 2000-01-07         1.913083e+12       8.154833e+11       1.119137e+12
#
#             Turnover_std_lag30  Close_mean_lag3  Close_mean_lag7  \
# Date
# 2000-01-03                 NaN              NaN              NaN
# 2000-01-04                 NaN       170.000000       170.000000
# 2000-01-05        1.688889e+12       171.899994       171.899994
# 2000-01-06        1.313207e+12       170.250000       170.250000
# 2000-01-07        1.119137e+12       169.683334       169.762497
#
#             Close_mean_lag30  Close_std_lag3  Close_std_lag7  Close_std_lag30
# Date
# 2000-01-03               NaN             NaN             NaN              NaN
# 2000-01-04        170.000000             NaN             NaN              NaN
# 2000-01-05        171.899994        2.687006        2.687006         2.687006
# 2000-01-06        170.250000        3.431836        3.431836         3.431836
# 2000-01-07        169.762497        3.628475        2.966866         2.966866
#
# [5 rows x 38 columns]

# %%
# adding month, week, day, day of week fields

stock.Date = pd.to_datetime(stock.Date, format="%Y-%m-%d")
stock["month"] = stock.Date.dt.month
stock["week"] = stock.Date.dt.isocalendar().week
stock["day"] = stock.Date.dt.day
stock["day_of_week"] = stock.Date.dt.dayofweek
display(stock.head())
# Out:
#                  Date    Open    High     Low   Close    VWAP  Volume  \
# Date
# 2000-01-03 2000-01-03  166.00  170.00  166.00  170.00  169.52   33259
# 2000-01-04 2000-01-04  182.00  183.45  171.00  173.80  174.99  168710
# 2000-01-05 2000-01-05  170.00  173.90  165.00  166.95  169.20  159820
# 2000-01-06 2000-01-06  168.00  170.00  165.30  168.30  168.44   85026
# 2000-01-07 2000-01-07  162.15  171.00  162.15  168.35  166.79   85144
#
#                 Turnover  High_mean_lag3  High_mean_lag7  ...  \
# Date                                                      ...
# 2000-01-03  5.638122e+11             NaN             NaN  ...
# 2000-01-04  2.952261e+12      170.000000      170.000000  ...
# 2000-01-05  2.704094e+12      176.725006      176.725006  ...
# 2000-01-06  1.432166e+12      175.783340      175.783340  ...
# 2000-01-07  1.420158e+12      175.783340      174.337494  ...
#
#             Close_mean_lag3  Close_mean_lag7  Close_mean_lag30  \
# Date
# 2000-01-03              NaN              NaN               NaN
# 2000-01-04       170.000000       170.000000        170.000000
# 2000-01-05       171.899994       171.899994        171.899994
# 2000-01-06       170.250000       170.250000        170.250000
# 2000-01-07       169.683334       169.762497        169.762497
#
#             Close_std_lag3  Close_std_lag7  Close_std_lag30  month  week  day  \
# Date
# 2000-01-03             NaN             NaN              NaN      1     1    3
# 2000-01-04             NaN             NaN              NaN      1     1    4
# 2000-01-05        2.687006        2.687006         2.687006      1     1    5
# 2000-01-06        3.431836        3.431836         3.431836      1     1    6
# 2000-01-07        3.628475        2.966866         2.966866      1     1    7
#
#             day_of_week
# Date
# 2000-01-03            0
# 2000-01-04            1
# 2000-01-05            2
# 2000-01-06            3
# 2000-01-07            4
#
# [5 rows x 42 columns]

# %%
# exogenous features

exogenous_features = ["High_mean_lag3", "High_std_lag3", "Low_mean_lag3", "Low_std_lag3",
                      "Volume_mean_lag3", "Volume_std_lag3", "Turnover_mean_lag3",
                      "Turnover_std_lag3","High_mean_lag7", "High_std_lag7", "Low_mean_lag7", "Low_std_lag7",
                      "Volume_mean_lag7", "Volume_std_lag7", "Turnover_mean_lag7",
                      "Turnover_std_lag7","High_mean_lag30", "High_std_lag30", "Low_mean_lag30", "Low_std_lag30",
                      "Volume_mean_lag30", "Volume_std_lag30", "Turnover_mean_lag30",
                      "Close_mean_lag3", "Close_mean_lag7","Close_mean_lag30","Close_std_lag3","Close_std_lag7","Close_std_lag30",
                      "Turnover_std_lag30","month","week","day","day_of_week"]

# %%
stock.dropna(inplace=True)
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5304 entries, 2000-01-05 to 2021-04-30
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 5304 non-null   datetime64[ns]
#  1   Open                 5304 non-null   float64
#  2   High                 5304 non-null   float64
#  3   Low                  5304 non-null   float64
#  4   Close                5304 non-null   float64
#  5   VWAP                 5304 non-null   float64
#  6   Volume               5304 non-null   int64
#  7   Turnover             5304 non-null   float64
#  8   High_mean_lag3       5304 non-null   float32
#  9   High_mean_lag7       5304 non-null   float32
#  10  High_mean_lag30      5304 non-null   float32
#  11  High_std_lag3        5304 non-null   float32
#  12  High_std_lag7        5304 non-null   float32
#  13  High_std_lag30       5304 non-null   float32
#  14  Low_mean_lag3        5304 non-null   float32
#  15  Low_mean_lag7        5304 non-null   float32
#  16  Low_mean_lag30       5304 non-null   float32
#  17  Low_std_lag3         5304 non-null   float32
#  18  Low_std_lag7         5304 non-null   float32
#  19  Low_std_lag30        5304 non-null   float32
#  20  Volume_mean_lag3     5304 non-null   float32
#  21  Volume_mean_lag7     5304 non-null   float32
#  22  Volume_mean_lag30    5304 non-null   float32
#  23  Volume_std_lag3      5304 non-null   float32
#  24  Volume_std_lag7      5304 non-null   float32
#  25  Volume_std_lag30     5304 non-null   float32
#  26  Turnover_mean_lag3   5304 non-null   float32
#  27  Turnover_mean_lag7   5304 non-null   float32
#  28  Turnover_mean_lag30  5304 non-null   float32
#  29  Turnover_std_lag3    5304 non-null   float32
#  30  Turnover_std_lag7    5304 non-null   float32
#  31  Turnover_std_lag30   5304 non-null   float32
#  32  Close_mean_lag3      5304 non-null   float32
#  33  Close_mean_lag7      5304 non-null   float32
#  34  Close_mean_lag30     5304 non-null   float32
#  35  Close_std_lag3       5304 non-null   float32
#  36  Close_std_lag7       5304 non-null   float32
#  37  Close_std_lag30      5304 non-null   float32
#  38  month                5304 non-null   int64
#  39  week                 5304 non-null   UInt32
#  40  day                  5304 non-null   int64
#  41  day_of_week          5304 non-null   int64
# dtypes: UInt32(1), datetime64[ns](1), float32(30), float64(6), int64(4)
# memory usage: 1.1+ MB

# %%
stock['Volume'] = stock['Volume'].astype('float64')
cols = ['month', 'week', 'day', 'day_of_week']
stock[cols] = stock[cols].astype('float32')

stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5304 entries, 2000-01-05 to 2021-04-30
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 5304 non-null   datetime64[ns]
#  1   Open                 5304 non-null   float64
#  2   High                 5304 non-null   float64
#  3   Low                  5304 non-null   float64
#  4   Close                5304 non-null   float64
#  5   VWAP                 5304 non-null   float64
#  6   Volume               5304 non-null   float64
#  7   Turnover             5304 non-null   float64
#  8   High_mean_lag3       5304 non-null   float32
#  9   High_mean_lag7       5304 non-null   float32
#  10  High_mean_lag30      5304 non-null   float32
#  11  High_std_lag3        5304 non-null   float32
#  12  High_std_lag7        5304 non-null   float32
#  13  High_std_lag30       5304 non-null   float32
#  14  Low_mean_lag3        5304 non-null   float32
#  15  Low_mean_lag7        5304 non-null   float32
#  16  Low_mean_lag30       5304 non-null   float32
#  17  Low_std_lag3         5304 non-null   float32
#  18  Low_std_lag7         5304 non-null   float32
#  19  Low_std_lag30        5304 non-null   float32
#  20  Volume_mean_lag3     5304 non-null   float32
#  21  Volume_mean_lag7     5304 non-null   float32
#  22  Volume_mean_lag30    5304 non-null   float32
#  23  Volume_std_lag3      5304 non-null   float32
#  24  Volume_std_lag7      5304 non-null   float32
#  25  Volume_std_lag30     5304 non-null   float32
#  26  Turnover_mean_lag3   5304 non-null   float32
#  27  Turnover_mean_lag7   5304 non-null   float32
#  28  Turnover_mean_lag30  5304 non-null   float32
#  29  Turnover_std_lag3    5304 non-null   float32
#  30  Turnover_std_lag7    5304 non-null   float32
#  31  Turnover_std_lag30   5304 non-null   float32
#  32  Close_mean_lag3      5304 non-null   float32
#  33  Close_mean_lag7      5304 non-null   float32
#  34  Close_mean_lag30     5304 non-null   float32
#  35  Close_std_lag3       5304 non-null   float32
#  36  Close_std_lag7       5304 non-null   float32
#  37  Close_std_lag30      5304 non-null   float32
#  38  month                5304 non-null   float32
#  39  week                 5304 non-null   float32
#  40  day                  5304 non-null   float32
#  41  day_of_week          5304 non-null   float32
# dtypes: datetime64[ns](1), float32(34), float64(7)
# memory usage: 1.1+ MB

# %% [markdown]
# # Normalization (MinMax scaling) and test-train splitting

# %%
# min max scaling(normalization) and train-test data splitting

train_len = len(stock[stock.Date < '2019'])

X = stock.loc[:, exogenous_features].reset_index(drop=True)
y = stock.loc[:, 'VWAP'].reset_index(drop=True)

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y.values.reshape(-1, 1))

X_train = X_scaled[0:train_len, :]
y_train = y_scaled[0:train_len, :]

X_test = X_scaled[train_len:, :]
y_test = y_scaled[train_len:, :]

# %% [markdown]
# # LSTM models

# %%
def lstm_model(lstm_layers, dense_layers, batch_input_shape):
    
    model = Sequential()
    
    if len(lstm_layers)==1:
        model.add(LSTM(lstm_layers[0], batch_input_shape=batch_input_shape))
        
#         model.add(Dropout(rate=0.2))
    
    else:
        
        model.add(LSTM(lstm_layers[0], batch_input_shape=batch_input_shape, 
                       return_sequences=True))
        
#         model.add(Dropout(rate=0.2))
        

        for units in lstm_layers[1:-1]:
            model.add(LSTM(units, return_sequences=True))
            
#             model.add(Dropout(rate=0.2))
            
        model.add(LSTM(lstm_layers[-1], return_sequences=False))
        
#         model.add(Dropout(rate=0.2))

    
    for units in dense_layers:
        model.add(Dense(units))

    # compile the model

    model.compile(loss='mean_squared_error', optimizer='adam')

    # return the model

    return model

    
def evaluate_model(model, X_train, y_train, X_test, y_test, nb_epoch, batch_size):
    
    # train the model
    
    history = model.fit(X_train, y_train, epochs=nb_epoch, batch_size=batch_size, 
                        validation_data=(X_test, y_test), 
                        callbacks=[EarlyStopping(monitor='val_loss', patience=5)],
                        verbose=0, shuffle=False)
    
    print_loss(history)
    
    model.summary()

    # predict
    
    y_pred = model.predict(X_test, batch_size=batch_size)

    return y_pred


def compute_errors(y_test, y_pred):

    rmse = sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)

    print(f'\nRMSE: {rmse} MAE: {mae}')
    
def print_loss(history):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='best')
    plt.show();

# %%
batch_size = 1 # number of sequences
timesteps = 1
nb_epoch = 40

# %%
X_train = X_train.reshape(X_train.shape[0], timesteps, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], timesteps, X_test.shape[1])

# %%
X_train.shape
# Out:
# (4727, 1, 34)

# %%
# (number of Sequences, time steps, number of Features) 

batch_input_shape = (batch_size, X_train.shape[1], X_train.shape[2])
batch_input_shape
# Out:
# (1, 1, 34)

# %% [markdown]
# # LSTM model 1

# %%
# build LSTM model with 
# LSTM layer of 32 units
# Dense layer of 1 unit 

lstm1 = lstm_model([32], [1], batch_input_shape)

y_pred1 = evaluate_model(lstm1, X_train, y_train, X_test, y_test, nb_epoch, batch_size)

y_pred1_ac = scaler_y.inverse_transform(y_pred1)

y_test_ac = y[train_len:]

compute_errors(y_test_ac, y_pred1_ac)
# Out:
# 2023-04-05 10:51:54.450184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 10:51:54.457737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 10:51:54.463694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 10:51:55.740438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 10:51:55.748997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 10:51:55.755149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 10:51:58.050688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 10:51:58.059150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 10:51:58.066587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 10:52:23.935047: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 10:52:23.940160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 10:52:23.944667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (1, 32)                   8576
#
#  dense_2 (Dense)             (1, 1)                    33
#
# =================================================================
# Total params: 8,609
# Trainable params: 8,609
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-05 11:02:02.919870: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:02:02.926071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:02:02.931764: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 577/577 [==============================] - 4s 4ms/step
#
# RMSE: 194.71079939786472 MAE: 155.21784265580993

# %%
results = pd.DataFrame({'Actual_VWAP':y_test_ac.values}, index=stock.index[train_len: ])

results['LSTM_1_VWAP'] = y_pred1_ac

results[["Actual_VWAP", "LSTM_1_VWAP"]].plot(figsize=(14, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # LSTM model 2

# %%
# build LSTM model with
# LSTM layer of 64 units 
# Dense layer of 1 unit 

lstm2 = lstm_model([64], [1], batch_input_shape)

y_pred2 = evaluate_model(lstm2, X_train, y_train, X_test, y_test, nb_epoch, batch_size)

y_pred2_ac = scaler_y.inverse_transform(y_pred2)

compute_errors(y_test_ac, y_pred2_ac)
# Out:
# 2023-04-05 11:02:07.728061: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:02:07.733634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:02:07.738635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:02:08.740285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:02:08.746748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:02:08.752546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:02:10.464205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:02:10.471631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:02:10.477057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:02:35.528682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:02:35.533855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:02:35.537977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (1, 64)                   25344
#
#  dense_3 (Dense)             (1, 1)                    65
#
# =================================================================
# Total params: 25,409
# Trainable params: 25,409
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-05 11:18:03.469261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:18:03.475882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:18:03.481278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 577/577 [==============================] - 4s 5ms/step
#
# RMSE: 201.46810130734275 MAE: 171.37929339694813

# %%
results['LSTM_2_VWAP'] = y_pred2_ac

results[["Actual_VWAP", "LSTM_2_VWAP"]].plot(figsize=(14, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # LSTM model 3

# %%
# build LSTM model with
# two LSTM layer of 64, 32 units 
# Dense layer of 1 units 

lstm3 = lstm_model([64, 32], [1], batch_input_shape)

y_pred3 = evaluate_model(lstm3, X_train, y_train, X_test, y_test, nb_epoch, batch_size)

y_pred3_ac = scaler_y.inverse_transform(y_pred3)

compute_errors(y_test_ac, y_pred3_ac)
# Out:
# 2023-04-05 11:28:15.737428: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:28:15.743767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:28:15.749420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:28:16.642668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:28:16.648080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:28:16.652894: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:28:17.889774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:28:17.898315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:28:17.905364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:28:18.890787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:28:18.901862: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:28:18.912546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:28:22.265393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:28:22.271860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:28:22.277325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:28:23.325251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:28:23.334234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:28:23.343265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:29:03.352955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:29:03.360036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:29:03.366960: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:29:04.023253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:29:04.028879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:29:04.034379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (1, 1, 64)                25344
#
#  lstm_10 (LSTM)              (1, 32)                   12416
#
#  dense_5 (Dense)             (1, 1)                    33
#
# =================================================================
# Total params: 37,793
# Trainable params: 37,793
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-05 11:50:46.185528: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:46.193763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:46.204083: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:50:47.018639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:47.025040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:47.031399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 577/577 [==============================] - 6s 5ms/step
#
# RMSE: 183.21821206329798 MAE: 130.04501974281033

# %%
results['LSTM_3_VWAP'] = y_pred3_ac

results[["Actual_VWAP", "LSTM_3_VWAP"]].plot(figsize=(14, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # LSTM model 4

# %%
# build LSTM model with
# two LSTM layer of 64, 32 units 
# two Dense layer of 16, 1 units 

lstm4 = lstm_model([64, 32], [16, 1], batch_input_shape)

y_pred4 = evaluate_model(lstm4, X_train, y_train, X_test, y_test, nb_epoch, batch_size)

y_pred4_ac = scaler_y.inverse_transform(y_pred4)

compute_errors(y_test_ac, y_pred4_ac)
# Out:
# 2023-04-05 11:50:52.558977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:52.564228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:52.568882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:50:53.204221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:53.209117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:53.213558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:50:54.182288: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:54.187385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:54.191889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:50:54.823686: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:54.829834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:54.834770: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:50:57.370425: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:57.378714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:57.384282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:50:58.067291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:50:58.073551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:50:58.078421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:51:39.596312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:51:39.605042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:51:39.612312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 11:51:40.446498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 11:51:40.454099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 11:51:40.461643: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (1, 1, 64)                25344
#
#  lstm_12 (LSTM)              (1, 32)                   12416
#
#  dense_6 (Dense)             (1, 16)                   528
#
#  dense_7 (Dense)             (1, 1)                    17
#
# =================================================================
# Total params: 38,305
# Trainable params: 38,305
# Non-trainable params: 0
# _________________________________________________________________
# 2023-04-05 12:14:51.418467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 12:14:51.424892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 12:14:51.430824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-04-05 12:14:52.201347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-04-05 12:14:52.206634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-04-05 12:14:52.211950: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 577/577 [==============================] - 7s 7ms/step
#
# RMSE: 179.48622476450612 MAE: 149.75185929799204

# %%
results['LSTM_4_VWAP'] = y_pred4_ac

results[["Actual_VWAP", "LSTM_4_VWAP"]].plot(figsize=(14, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Simple RNN model

# %%
# build Simple RNN model with
# simple RNN layer of 64 units
# two Dense layers of 16, 1 units 


rnn = Sequential()

rnn.add(SimpleRNN(64, batch_input_shape=(batch_size, X_train.shape[1], X_train.shape[2])))

rnn.add(Dense(16))

rnn.add(Dense(1))

rnn.compile(loss='mean_squared_error', optimizer='adam')

y_pred5 = evaluate_model(rnn, X_train, y_train, X_test, y_test, nb_epoch, batch_size)

y_pred5_ac = scaler_y.inverse_transform(y_pred5)

compute_errors(y_test_ac, y_pred5_ac)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (1, 64)                   6336
#
#  dense_8 (Dense)             (1, 16)                   1040
#
#  dense_9 (Dense)             (1, 1)                    17
#
# =================================================================
# Total params: 7,393
# Trainable params: 7,393
# Non-trainable params: 0
# _________________________________________________________________
# 577/577 [==============================] - 3s 5ms/step
#
# RMSE: 554.9521319574548 MAE: 476.4346838865495

# %%
results['SimpleRNN_VWAP'] = y_pred5_ac

results[["Actual_VWAP", "SimpleRNN_VWAP"]].plot(figsize=(14, 7))
# Out:
# RMSE: 554.9521319574548 MAE: 476.4346838865495
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Auto Arimax model

# %%
# ARIMA with exogenous_features (ARIMAX)

stock_train = stock[stock.Date < '2019']
stock_test = stock[stock.Date >= '2019']


arima = auto_arima(stock_train.VWAP, exogenous=stock_train[exogenous_features], seasonal=True, m=12,
                   trace=True, error_action="ignore", suppress_warnings=True)

arima.fit(stock_train.VWAP, exogenous=stock_train[exogenous_features])

arima.summary()

y_pred6 = arima.predict(n_periods=len(stock_test), exogenous=stock_test[exogenous_features])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=46764.592, Time=9.50 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=46761.139, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=46760.841, Time=0.73 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=46760.914, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=46759.837, Time=0.06 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=46763.064, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=46763.064, Time=0.49 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=46765.079, Time=0.72 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=46758.951, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=46760.840, Time=0.59 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=46762.852, Time=0.83 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=46760.620, Time=0.35 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=46760.618, Time=1.26 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=46759.024, Time=0.38 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=46761.733, Time=2.32 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=46757.608, Time=0.07 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=46759.491, Time=0.27 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=46759.491, Time=0.36 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=46761.488, Time=0.41 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=46759.266, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=46759.254, Time=0.84 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=46757.682, Time=0.21 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=46760.547, Time=0.37 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12]
# Total fit time: 21.376 seconds
# /home/vinay/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# plotting the best ARIMA model which has the lowest AIC for test data

compute_errors(y_test_ac, y_pred6)

y_pred6.index = results.index

results["ARIMAX_VWAP"] = y_pred6

results[["Actual_VWAP", "ARIMAX_VWAP"]].plot(figsize=(14, 7))
# Out:
# RMSE: 776.8334370974753 MAE: 672.1435556137563
# <AxesSubplot:xlabel='Date'>

# %%
results
# Out:
#             Actual_VWAP  LSTM_1_VWAP  LSTM_2_VWAP  LSTM_3_VWAP  LSTM_4_VWAP  \
# Date
# 2019-01-01      2131.37  2156.542236  2152.673340  2160.071533  2062.828369
# 2019-01-02      2132.45  2161.591553  2166.687012  2166.118896  2064.568848
# 2019-01-03      2112.75  2162.863770  2175.377441  2168.665283  2063.906494
# 2019-01-04      2119.55  2166.708496  2180.873535  2174.745117  2066.026855
# 2019-01-07      2128.37  2162.184326  2152.730225  2170.451660  2093.291748
# ...                 ...          ...          ...          ...          ...
# 2021-04-26      1413.19  1687.622803  1728.164062  1395.157471  1625.229492
# 2021-04-27      1430.40  1684.693481  1730.848267  1383.521118  1625.716309
# 2021-04-28      1463.19  1710.713257  1756.090454  1414.504028  1631.936157
# 2021-04-29      1481.15  1720.955078  1768.616943  1413.546509  1641.192139
# 2021-04-30      1421.13  1740.084473  1792.908081  1436.336304  1658.949951
#
#             SimpleRNN_VWAP  ARIMAX_VWAP     fbp_VWAP
# Date
# 2019-01-01     2114.648926  2124.331157  2106.711844
# 2019-01-02     2114.646240  2124.330593  2147.490341
# 2019-01-03     2116.710693  2124.330576  2146.434127
# 2019-01-04     2124.102783  2124.330576  2142.979536
# 2019-01-07     2128.155029  2124.330576  2122.877828
# ...                    ...          ...          ...
# 2021-04-26     1967.808838  2124.330576  1433.740527
# 2021-04-27     1975.531372  2124.330576  1436.849154
# 2021-04-28     1971.046875  2124.330576  1451.226056
# 2021-04-29     1967.118896  2124.330576  1470.940035
# 2021-04-30     1966.696167  2124.330576  1489.418365
#
# [577 rows x 8 columns]

# %% [markdown]
# # fbprophet model

# %%
fbp = Prophet()

for feature in exogenous_features:
    fbp.add_regressor(feature)

fbp.fit(stock_train[["Date", "VWAP"] + exogenous_features].rename(columns={"Date": "ds", "VWAP": "y"}))

y_pred7 = fbp.predict(stock_test[["Date", "VWAP"] + exogenous_features].rename(columns={"Date": "ds"}))
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /home/vinay/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# Initial log joint probability = -107.841
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       16959.6    0.00596961       23957.6           1           1      117
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       17419.9   0.000451402       7116.02           1           1      223
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       17565.1    0.00140488       6491.53           1           1      328
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       17635.4    0.00484008       18201.1           1           1      434
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       17694.3   0.000184488       2814.24           1           1      539
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       17716.2   0.000234605       3430.69           1           1      645
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       17729.8    2.9038e-05       4021.82      0.5932      0.5932      749
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       17743.1   9.48828e-05       2301.44      0.2981      0.2981      856
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       17747.5   0.000102612       896.286           1           1      964
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999         17750   0.000526198       1244.78           1           1     1072
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       17753.6   0.000347329       2613.95           1           1     1178
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199         17756   7.58359e-05       1101.54      0.6441      0.6441     1285
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299       17758.4   8.25936e-05        1087.1           1           1     1390
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399         17760    0.00017104       742.802           1           1     1499
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499         17761   6.61374e-05        526.43           1           1     1605
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599       17763.5   0.000729056       2047.92           1           1     1709
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       17767.4   0.000370141       1269.18           1           1     1820
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       17768.1   0.000126931       545.881           1           1     1931
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899       17768.6   0.000111908       359.901           1           1     2037
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       17769.4   0.000568243       540.312           1           1     2145
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099       17771.1   0.000598659        1438.2           1           1     2253
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       17772.2   0.000528515        1224.5           1           1     2368
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2299       17773.8   0.000202568       755.345           1           1     2478
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       17774.2   1.58025e-05       242.176           1           1     2589
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       17774.5   3.63368e-05       346.511           1           1     2703
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       17774.7   1.44588e-06        345.57      0.2669      0.2669     2810
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       17774.9   0.000181831       446.704           1           1     2920
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2799       17775.1   1.45395e-05       457.757     0.09971     0.09971     3029
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2899       17775.3   1.22756e-05       204.875      0.7088      0.7088     3139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2999       17775.4   0.000147181        304.63           1           1     3247
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3099       17775.7   7.43697e-05       424.566           1           1     3351
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3199       17775.8   0.000254182       200.511           1           1     3460
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3299         17776   7.85389e-05       1046.96      0.8506      0.8506     3565
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3399       17776.3   0.000183228       872.213           1           1     3684
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3499       17776.4   5.16432e-05       176.501       0.849       0.849     3797
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3599       17776.5   2.95535e-05       423.161           1           1     3912
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3699       17776.5   2.18812e-05       314.983           1           1     4025
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3773       17776.6   4.37754e-06       583.745   5.221e-09       0.001     4147  LS failed, Hessian reset
#     3799       17776.7   8.78102e-06       309.232      0.6062      0.6062     4174
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3899       17776.7   2.54377e-05        100.55           1           1     4281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     3976       17776.8     2.492e-06       71.0728           1           1     4366
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# /home/vinay/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# /home/vinay/anaconda3/lib/python3.9/site-packages/fbprophet/forecaster.py:891: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
compute_errors(y_test_ac, y_pred7.yhat.values)

results["fbp_VWAP"] = y_pred7.yhat.values

results[["Actual_VWAP", "fbp_VWAP"]].plot(figsize=(14, 7))
# Out:
# RMSE: 55.80324472922854 MAE: 25.463452949787857
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Conclusions
#
# RNN performs poorly, in comparison to LTSM model. When we move from RNN to LSTM, we are introducing more & more controlling knobs, which control the flow and mixing of Inputs as per trained Weights. And thus, bringing in more flexibility in controlling the outputs. Thus, we obtain better results in LTSM.
#
# Auto ARIMAX is a great baseline model but newer algorithms like Facebook's Prophet are extremely powerful.
#
# Lag-based features are very useful in providing trends information about the time series data. Rolling statistics are a common way of generating these.
#
# Exogenous regressors help in providing external information about the time series. They tend to be very important in most models.
#
# Converting a time series to stationary and then modelling is a common approach for building solutions and can significantly improve results.

# %%
results[["Actual_VWAP", "LSTM_4_VWAP", "SimpleRNN_VWAP", "ARIMAX_VWAP", "fbp_VWAP"]].plot(figsize=(16, 10))
# Out:
# <AxesSubplot:xlabel='Date'>
